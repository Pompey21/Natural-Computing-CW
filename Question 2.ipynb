# %% [markdown]
# # Genetic Program Example - adapted from TinyGP by Moshesipper

# %% [markdown]
# Import libraries

# %%
from random import random, randint, seed, randrange
from statistics import mean
from copy import deepcopy
import numpy as np
from itertools import combinations
import math

# %% [markdown]
# ## Define parameters

# %% [markdown]
# We must now define our parameters, and allow for bloat control.

# %%
POP_SIZE        = 60   # population size
MIN_DEPTH       = 2    # minimal initial random tree depth
MAX_DEPTH       = 5    # maximal initial random tree depth
GENERATIONS     = 250  # maximal number of generations to run evolution
TOURNAMENT_SIZE = 5    # size of tournament for tournament selection
XO_RATE         = 0.8  # crossover rate 
PROB_MUTATION   = 0.2  # per-node mutation probability

# %% [markdown]
# ## Defining non-terminals and terminals

# %% [markdown]
# Define functions for non terminal set - this can be done natively in functional programming languages.

# %%
# functions taking two arguments
def add(x, y): return x + y
def sub(x, y): return x - y
def mul(x, y): return x * y
def div(x,y): 
    if y != 0:
        return x/y
    else: 
        return 2**(31-1)

# %%
# functions taking one argument
def sin(x): return math.sin(x)
def cos(x): return math.cos(x)
def aBs(x): return abs(x)
def eXp(x): 
    return math.exp(x)
def power_1(x): return x
def power_2(x): return x**2
def power_3(x): return x**3
def power_4(x): return x**4
def power_reverse_1(x): return x
def power_reverse_2(x): 
    return x**(1/2)
def power_reverse_3(x): return x**(1/3)
def power_reverse_4(x): return x**(1/4)

# %% [markdown]
# Define terminal and non-terminal sets

# %%
FUNCTIONS_2_ARGS = [add, sub, mul]
FUNCTIONS_1_ARG = [sin, cos, aBs, eXp, power_1, power_2, power_3, power_4, power_reverse_1, power_reverse_2,
                                                                        power_reverse_3, power_reverse_4]

def generate_terminals(dim):
    TERMINALS = [-2, -1, 0, 1, 2]
    for i in range(1,dim+1):
        x = f'x{i}'
        TERMINALS.append(x)
    return TERMINALS

TERMINALS = generate_terminals(2)
print(generate_terminals(3))
# Out:
# [-2, -1, 0, 1, 2, 'x1', 'x2', 'x3']

# %% [markdown]
# ## Managing our dataset

# %% [markdown]
# In usual settings you will have a dataset which you are working from, much in the same way as in traditional ML tasks; however, for the assignment and for observing, we will consider a target function and a create a dataset from that.

# %%
# def target_func(x): # evolution's target
#     return x*x + 2*x + 1

# %%
# def generate_dataset(): # generate 101 data points from target_func
#     dataset = []
#     for x in range(-100,101,2): 
#         x /= 100
#         dataset.append([x, target_func(x)])
#     return dataset

# %% [markdown]
# ## Sphere method

# %%
def sphere_function(pos):
    big_sum = 0
    for i in range(len(pos)):
        big_sum = big_sum + pos[i]**2
    return big_sum

# %%
def generate_dataset(dims): # generate 101 data points from target_func
    dataset = []
    for i in range(100):
        n_tuple = []
        for dim in range(dims):
            x = randrange(-500, 500)/100
            n_tuple.append(x)
        dataset.append((n_tuple,sphere_function(n_tuple)))
    return dataset

def flip_coin():
    if randrange(0,100) > 50:
        return True
    else:
        return False

# %%
dataset = generate_dataset(2)
dataset_result = dataset
print(dataset_result)
# Out:
# [([2.97, -3.83], 23.489800000000002), ([2.89, 3.71], 22.1162), ([-3.4, -2.61], 18.372099999999996), ([-1.54, -4.92], 26.578), ([3.96, 3.58], 28.497999999999998), ([-2.69, 0.14], 7.255699999999999), ([1.63, -1.75], 5.7194), ([1.06, 1.65], 3.8461), ([-0.31, -2.64], 7.0657000000000005), ([-3.2, -4.44], 29.953600000000005), ([4.74, 2.76], 30.0852), ([4.2, 2.6], 24.400000000000002), ([-0.28, 2.45], 6.0809000000000015), ([-4.35, 0.67], 19.371399999999994), ([-2.5, 4.38], 25.4344), ([-3.36, -1.23], 12.802499999999998), ([-2.94, -2.97], 17.4645), ([-1.81, -4.79], 26.2202), ([-4.02, 3.26], 26.787999999999997), ([4.03, 1.1], 17.450900000000004), ([2.61, 1.59], 9.3402), ([-3.09, -4.57], 30.433), ([2.38, 1.25], 7.2269), ([-0.98, 2.61], 7.772499999999999), ([3.62, -2.82], 21.0568), ([0.75, -4.28], 18.8809), ([-2.23, -4.12], 21.9473), ([3.57, 1.12], 13.9993), ([2.03, 2.85], 12.2434), ([-1.37, 2.89], 10.229000000000001), ([-2.33, 1.09], 6.617000000000001), ([-0.82, -2.73], 8.1253), ([1.02, -3.68], 14.5828), ([0.78, -4.36], 19.618000000000002), ([-2.67, 0.9], 7.9389), ([-2.01, 2.48], 10.1905), ([-3.89, -4.71], 37.3162), ([2.86, 3.57], 20.9245), ([3.65, -1.97], 17.2034), ([2.31, 4.66], 27.051700000000004), ([-4.9, 3.64], 37.259600000000006), ([-2.34, -1.88], 9.009999999999998), ([-3.31, -1.13], 12.233), ([1.72, 0.78], 3.5667999999999997), ([0.02, 0.76], 0.578), ([-4.31, -3.61], 31.608199999999997), ([0.26, -0.07], 0.07250000000000001), ([-3.5, -1.06], 13.3736), ([1.56, -2.19], 7.2297), ([-0.32, -0.58], 0.43879999999999997), ([2.23, -0.01], 4.973), ([4.11, -1.95], 20.6946), ([2.13, 4.53], 25.0578), ([3.15, 4.76], 32.5801), ([-0.47, -2.33], 5.649800000000001), ([-2.37, 4.07], 22.181800000000003), ([-4.34, 1.44], 20.9092), ([1.3, 2.09], 6.0581), ([-3.93, 2.12], 19.939300000000003), ([-0.59, 3.93], 15.793000000000001), ([-2.38, 1.91], 9.3125), ([-1.49, -3.4], 13.7801), ([4.26, -0.04], 18.149199999999997), ([1.62, 1.59], 5.152500000000001), ([1.77, 3.37], 14.489800000000002), ([1.38, -1.14], 3.2039999999999997), ([-2.96, 4.02], 24.921999999999997), ([-3.38, 1.25], 12.986899999999999), ([4.22, 0.34], 17.924), ([-1.93, 1.35], 5.5474), ([3.64, 1.09], 14.437700000000001), ([1.89, -4.41], 23.0202), ([-4.2, -2.46], 23.6916), ([1.5, 4.07], 18.8149), ([1.11, -2.32], 6.6145), ([3.44, 2.29], 17.0777), ([1.77, 4.98], 27.933300000000003), ([-2.16, 1.82], 7.978000000000001), ([1.0, -4.82], 24.232400000000002), ([1.33, -2.07], 6.0538), ([-0.85, 4.79], 23.6666), ([3.15, -1.99], 13.8826), ([-1.28, -0.29], 1.7225000000000001), ([3.5, 0.83], 12.9389), ([-0.94, -3.78], 15.171999999999999), ([2.21, -3.52], 17.2745), ([1.15, -2.32], 6.704899999999999), ([-4.8, -2.77], 30.712899999999998), ([1.99, -0.12], 3.9745000000000004), ([-2.79, -1.61], 10.3762), ([-2.05, -4.36], 23.212100000000003), ([3.82, 4.49], 34.752500000000005), ([-1.51, 2.11], 6.7322), ([4.48, 0.15], 20.092900000000004), ([0.23, 1.24], 1.5905), ([2.86, 4.43], 27.804499999999997), ([-4.51, 1.25], 21.9026), ([-3.17, 2.4], 15.8089), ([-2.71, 0.57], 7.6690000000000005), ([1.8, -0.98], 4.2004)]

# %% [markdown]
# ## Creating the genetic program class

# %%
class GPTree:
    def __init__(self, data = None, left = None, right = None):
        self.data  = data
        self.left  = left
        self.right = right
        
    def node_label(self): # string label
        if (self.data in FUNCTIONS_2_ARGS or self.data in FUNCTIONS_1_ARG):
            return self.data.__name__
        else: 
            return str(self.data)
    
    def print_tree(self, prefix = ""): # textual printout
        print("%s%s" % (prefix, self.node_label()))        
        if self.left:  self.left.print_tree (prefix + "   ")
        if self.right: self.right.print_tree(prefix + "   ")

    def compute_tree(self, x): 
        if (self.data in FUNCTIONS_2_ARGS): 
            return self.data(self.left.compute_tree(x), self.right.compute_tree(x))
        elif (self.data in FUNCTIONS_1_ARG):
#             print(x)
#             print(self.left.compute_tree(x))
#             print(self.data(self.left.compute_tree(x)))
            return self.data(self.left.compute_tree(x))
        elif type(self.data) is str: 
            if self.data[0] == 'x': return x[int(self.data[1:])-1]
        else: return self.data
            
    def random_tree(self, grow, max_depth, depth = 0): # create random tree using either grow or full method
        if depth < MIN_DEPTH or (depth < max_depth and not grow): 
            if flip_coin() == True:
                self.data = FUNCTIONS_2_ARGS[randint(0, len(FUNCTIONS_2_ARGS)-1)]
            else:
                self.data = FUNCTIONS_1_ARG[randint(0, len(FUNCTIONS_1_ARG)-1)]
        elif depth >= max_depth:   
            self.data = TERMINALS[randint(0, len(TERMINALS)-1)]
        else: # intermediate depth, grow
            if random () > 0.5: 
                self.data = TERMINALS[randint(0, len(TERMINALS)-1)]
            else:
                if flip_coin() == True:
                    self.data = FUNCTIONS_2_ARGS[randint(0, len(FUNCTIONS_2_ARGS)-1)]
                else:
                    self.data = FUNCTIONS_1_ARG[randint(0, len(FUNCTIONS_1_ARG)-1)]
        if self.data in FUNCTIONS_2_ARGS:
            self.left = GPTree()          
            self.left.random_tree(grow, max_depth, depth = depth + 1)            
            self.right = GPTree()
            self.right.random_tree(grow, max_depth, depth = depth + 1)
        elif self.data in FUNCTIONS_1_ARG:
            self.left = GPTree()          
            self.left.random_tree(grow, max_depth, depth = depth + 1)

    def mutation(self):
        if random() < PROB_MUTATION: # mutate at this node
            self.random_tree(grow = True, max_depth = 2)
        elif self.left: self.left.mutation()
        elif self.right: self.right.mutation() 

    def size(self): # tree size in nodes
        if self.data in TERMINALS: return 1
        l = self.left.size()  if self.left  else 0
        r = self.right.size() if self.right else 0
        return 1 + l + r

    def build_subtree(self): # count is list in order to pass "by reference"
        t = GPTree()
        t.data = self.data
        if self.left:  t.left  = self.left.build_subtree()
        if self.right: t.right = self.right.build_subtree()
        return t
                        
    def scan_tree(self, count, second): # note: count is list, so it's passed "by reference"
        count[0] -= 1            
        if count[0] <= 1: 
            if not second: # return subtree rooted here
                return self.build_subtree()
            else: # glue subtree here
                self.data  = second.data
                self.left  = second.left
                self.right = second.right
        else:  
            ret = None              
            if self.left  and count[0] > 1: ret = self.left.scan_tree(count, second)  
            if self.right and count[0] > 1: ret = self.right.scan_tree(count, second)  
            return ret

    def crossover(self, other): # xo 2 trees at random nodes
        if random() < XO_RATE:
            second = other.scan_tree([randint(1, other.size())], None) # 2nd random subtree
            self.scan_tree([randint(1, self.size())], second) # 2nd subtree "glued" inside 1st tree

# %% [markdown]
# ## Fitness and selection

# %%
def fitness(individual, dataset): # inverse mean absolute error over dataset normalized to [0,1]
    try:
        return 1 / (1 + mean([abs(individual.compute_tree(ds[0]) - ds[1]) for ds in dataset]))
    except Exception:
        return 0

# %% [markdown]
# In the example we are using tournament based fitness. What benefits and negatives does tournament selection have?

# %%
def selection(population, fitnesses): # select one individual using tournament selection
    tournament = [randint(0, len(population)-1) for i in range(TOURNAMENT_SIZE)] # select tournament contenders
    tournament_fitnesses = [fitnesses[tournament[i]] for i in range(TOURNAMENT_SIZE)]
    return deepcopy(population[tournament[tournament_fitnesses.index(max(tournament_fitnesses))]])

# %% [markdown]
# Try to implement a roulette wheel selection for this and compare your results.

# %%
def roulette_selection(population, fitnesses):
    pass

# %%
def init_population(): # ramped half-and-half
    pop = []
    for md in range(3, MAX_DEPTH + 1):
        for i in range(int(POP_SIZE/6)):
            t = GPTree()
            t.random_tree(grow = True, max_depth = md) # grow
            pop.append(t) 
        for i in range(int(POP_SIZE/6)):
            t = GPTree()
            t.random_tree(grow = False, max_depth = md) # full
            pop.append(t) 
    return pop

# %% [markdown]
# ##  Main Loop

# %%
    dims = 2
    dataset = generate_dataset(dims)
    population = init_population() 
    best_of_run = None
    best_of_run_f = 0
    best_of_run_gen = 0
    fitnesses = [fitness(population[i], dataset) for i in range(POP_SIZE)]

    # go evolution!
    for gen in range(GENERATIONS):        
        nextgen_population=[]
        for i in range(POP_SIZE):
            parent1 = selection(population, fitnesses)
            parent2 = selection(population, fitnesses)
            parent1.crossover(parent2)
            parent1.mutation()
            nextgen_population.append(parent1)
        population=nextgen_population
        fitnesses = [fitness(population[i], dataset) for i in range(POP_SIZE)]
        if max(fitnesses) > best_of_run_f:
            best_of_run_f = max(fitnesses)
            best_of_run_gen = gen
            best_of_run = deepcopy(population[fitnesses.index(max(fitnesses))])
            print("________________________")
            print("gen:", gen, ", best_of_run_f:", round(max(fitnesses),3), ", best_of_run:") 
            best_of_run.print_tree()
        if best_of_run_f == 1: break   
    
    print("\n\n_________________________________________________\nEND OF RUN\nbest_of_run attained at gen " + str(best_of_run_gen) +\
          " and has f=" + str(round(best_of_run_f,3)))
    best_of_run.print_tree()
# Out:
# ________________________
# gen: 0 , best_of_run_f: 0.106 , best_of_run:
# eXp
#    eXp
#       power_2
#          aBs
#             power_reverse_3
#                1
# ________________________
# gen: 1 , best_of_run_f: 0.126 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       -2
#       x1
# ________________________
# gen: 3 , best_of_run_f: 0.129 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             power_3
#                2
#          power_reverse_2
#             power_reverse_1
#                power_2
#                   mul
#                      power_3
#                         2
#                      sub
#                         0
#                         1
#       x1
# ________________________
# gen: 5 , best_of_run_f: 0.134 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             power_3
#                2
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         add
#                            1
#                            power_1
#                               x1
#                         power_reverse_4
#                            power_3
#                               aBs
#                                  -2
#       x1
# ________________________
# gen: 7 , best_of_run_f: 0.137 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             power_3
#                2
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         add
#                            sub
#                               sub
#                                  cos
#                                     power_3
#                                        2
#                                  power_reverse_2
#                                     power_reverse_1
#                                        power_reverse_1
#                                           power_1
#                                              power_1
#                                                 0
#                               x1
#                            x2
#                         power_reverse_4
#                            power_3
#                               aBs
#                                  -2
#       x1
# ________________________
# gen: 8 , best_of_run_f: 0.142 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             power_3
#                2
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         add
#                            sub
#                               sub
#                                  cos
#                                     power_3
#                                        2
#                                  power_reverse_2
#                                     power_reverse_1
#                                        power_reverse_1
#                                           x1
#                               x1
#                            x2
#                         power_reverse_4
#                            power_3
#                               aBs
#                                  -2
#       x1
# ________________________
# gen: 10 , best_of_run_f: 0.145 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             x1
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         sub
#                            sub
#                               cos
#                                  power_3
#                                     2
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_2
#                                           add
#                                              add
#                                                 sub
#                                                    sub
#                                                       power_3
#                                                          aBs
#                                                             0
#                                                       power_reverse_2
#                                                          power_reverse_1
#                                                             power_reverse_1
#                                                                power_1
#                                                                   power_1
#                                                                      0
#                                                    x1
#                                                 x2
#                                              power_reverse_4
#                                                 power_3
#                                                    aBs
#                                                       -2
#                            x1
#                         power_reverse_4
#                            power_3
#                               aBs
#                                  0
#       x1
# ________________________
# gen: 15 , best_of_run_f: 0.147 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             x1
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         sub
#                            sub
#                               cos
#                                  power_3
#                                     -2
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_2
#                                           add
#                                              add
#                                                 sub
#                                                    sub
#                                                       power_3
#                                                          aBs
#                                                             0
#                                                       power_reverse_2
#                                                          power_reverse_1
#                                                             power_reverse_1
#                                                                power_1
#                                                                   power_1
#                                                                      0
#                                                    x1
#                                                 x2
#                                              power_reverse_4
#                                                 power_3
#                                                    aBs
#                                                       -2
#                            x1
#                         power_reverse_4
#                            add
#                               power_2
#                                  add
#                                     1
#                                     x2
#                               x2
#       x1
# ________________________
# gen: 17 , best_of_run_f: 0.154 , best_of_run:
# add
#    power_reverse_1
#       sub
#          aBs
#             x1
#          add
#             0
#             -1
#       mul
#          x2
#          x2
#    power_2
#       x2
# ________________________
# gen: 23 , best_of_run_f: 0.154 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             x1
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         sub
#                            sub
#                               cos
#                                  power_3
#                                     -2
#                               power_reverse_2
#                                  1
#                            x1
#                         power_reverse_4
#                            add
#                               sub
#                                  add
#                                     aBs
#                                        x1
#                                     power_reverse_2
#                                        -2
#                                  -2
#                               x2
#       x1
# ________________________
# gen: 24 , best_of_run_f: 0.156 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             x1
#          power_reverse_2
#             power_reverse_1
#                power_reverse_1
#                   power_2
#                      add
#                         sub
#                            sub
#                               cos
#                                  power_3
#                                     -2
#                               power_reverse_2
#                                  cos
#                                     power_3
#                                        2
#                            x1
#                         power_reverse_4
#                            add
#                               sub
#                                  add
#                                     aBs
#                                        x1
#                                     power_reverse_2
#                                        -2
#                                  -2
#                               x2
#       x1
# ________________________
# gen: 25 , best_of_run_f: 0.209 , best_of_run:
# sub
#    mul
#       x2
#       x2
#    sub
#       sub
#          cos
#             x1
#          power_3
#             aBs
#                sub
#                   power_3
#                      aBs
#                         0
#                   power_reverse_2
#                      power_reverse_1
#                         sub
#                            sin
#                               sin
#                                  0
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_1
#                                           power_1
#                                              0
#                            x1
#       x1
# ________________________
# gen: 32 , best_of_run_f: 0.373 , best_of_run:
# add
#    power_1
#       add
#          mul
#             add
#                power_2
#                   x1
#                power_reverse_1
#                   -1
#             power_2
#                -1
#          aBs
#             x1
#       mul
#          sub
#             cos
#                power_3
#                   power_3
#                      aBs
#                         sub
#                            power_3
#                               aBs
#                                  0
#                            power_reverse_2
#                               power_reverse_1
#                                  sub
#                                     sin
#                                        power_reverse_2
#                                           power_reverse_1
#                                              power_reverse_1
#                                                 power_2
#                                                    add
#                                                       sub
#                                                          sub
#                                                             cos
#                                                                power_3
#                                                                   -2
#                                                             power_reverse_2
#                                                                power_reverse_1
#                                                                   power_reverse_1
#                                                                      sub
#                                                                         mul
#                                                                            x2
#                                                                            x2
#                                                                         x1
#                                                          x1
#                                                       power_reverse_4
#                                                          add
#                                                             x2
#                                                             x2
#                                        power_reverse_2
#                                           power_reverse_1
#                                              power_reverse_1
#                                                 power_1
#                                                    power_1
#                                                       0
#                                     x1
#             power_reverse_2
#                power_reverse_1
#                   power_reverse_1
#                      power_2
#                         cos
#                            power_3
#                               -2
#          sub
#             mul
#                x2
#                x2
#             sub
#                sub
#                   cos
#                      power_3
#                         aBs
#                            sub
#                               power_3
#                                  aBs
#                                     0
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_1
#                                           -2
#                   power_reverse_2
#                      power_reverse_1
#                         power_reverse_1
#                            power_2
#                               add
#                                  power_3
#                                     -2
#                                  power_reverse_4
#                                     add
#                                        x2
#                                        x2
#                x1
#    power_2
#       x2
# ________________________
# gen: 33 , best_of_run_f: 0.457 , best_of_run:
# add
#    power_1
#       add
#          power_2
#             x1
#          power_reverse_4
#             2
#       mul
#          sub
#             cos
#                power_3
#                   power_3
#                      aBs
#                         sub
#                            power_3
#                               aBs
#                                  0
#                            power_reverse_2
#                               power_reverse_1
#                                  sub
#                                     sin
#                                        power_reverse_2
#                                           power_reverse_1
#                                              power_reverse_1
#                                                 power_2
#                                                    add
#                                                       sub
#                                                          sub
#                                                             cos
#                                                                power_3
#                                                                   -2
#                                                             power_reverse_2
#                                                                power_reverse_1
#                                                                   power_reverse_1
#                                                                      sub
#                                                                         mul
#                                                                            x2
#                                                                            x2
#                                                                         x1
#                                                          x1
#                                                       power_reverse_4
#                                                          add
#                                                             x2
#                                                             x2
#                                        power_reverse_2
#                                           power_reverse_1
#                                              power_reverse_1
#                                                 power_1
#                                                    power_1
#                                                       0
#                                     x1
#             power_reverse_2
#                power_reverse_1
#                   power_reverse_1
#                      power_2
#                         cos
#                            power_3
#                               -2
#          sub
#             mul
#                x2
#                x2
#             sub
#                sub
#                   cos
#                      power_3
#                         aBs
#                            sub
#                               power_3
#                                  aBs
#                                     0
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_1
#                                           -2
#                   power_reverse_2
#                      power_reverse_1
#                         power_reverse_1
#                            power_2
#                               add
#                                  power_3
#                                     -2
#                                  power_reverse_4
#                                     add
#                                        x2
#                                        x2
#                x1
#    power_2
#       x2
# ________________________
# gen: 35 , best_of_run_f: 0.5 , best_of_run:
# add
#    power_1
#       add
#          add
#             add
#                -1
#                0
#             power_reverse_4
#                0
#          power_2
#             x1
#       mul
#          sub
#             cos
#                power_3
#                   power_3
#                      aBs
#                         sub
#                            power_3
#                               aBs
#                                  0
#                            power_reverse_2
#                               power_reverse_1
#                                  power_reverse_2
#                                     power_reverse_1
#                                        power_reverse_1
#                                           power_2
#                                              add
#                                                 sub
#                                                    sub
#                                                       cos
#                                                          power_3
#                                                             -2
#                                                       power_reverse_2
#                                                          power_reverse_1
#                                                             x1
#                                                    x1
#                                                 power_reverse_4
#                                                    add
#                                                       x2
#                                                       x2
#             power_reverse_2
#                power_reverse_1
#                   power_reverse_1
#                      power_2
#                         cos
#                            power_3
#                               -2
#          sub
#             mul
#                x2
#                x2
#             sub
#                sub
#                   cos
#                      power_3
#                         aBs
#                            sub
#                               power_3
#                                  aBs
#                                     0
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_1
#                                           -2
#                   power_reverse_2
#                      power_reverse_1
#                         power_reverse_1
#                            power_2
#                               add
#                                  power_3
#                                     -2
#                                  power_reverse_4
#                                     add
#                                        x2
#                                        x2
#                x1
#    power_2
#       x2
# ________________________
# gen: 38 , best_of_run_f: 1.0 , best_of_run:
# add
#    power_1
#       add
#          add
#             add
#                mul
#                   cos
#                      0
#                   sin
#                      0
#                0
#             power_reverse_4
#                0
#          power_2
#             x1
#       mul
#          sub
#             cos
#                power_3
#                   power_3
#                      aBs
#                         sub
#                            power_3
#                               aBs
#                                  0
#                            power_reverse_2
#                               power_reverse_1
#                                  power_reverse_2
#                                     power_reverse_1
#                                        power_reverse_1
#                                           power_2
#                                              add
#                                                 sub
#                                                    sub
#                                                       cos
#                                                          power_3
#                                                             -2
#                                                       power_reverse_2
#                                                          power_reverse_1
#                                                             x1
#                                                    x1
#                                                 power_reverse_4
#                                                    add
#                                                       x2
#                                                       x2
#             power_reverse_2
#                power_reverse_1
#                   power_reverse_1
#                      power_2
#                         cos
#                            power_3
#                               -2
#          sub
#             mul
#                x2
#                x2
#             sub
#                sub
#                   cos
#                      power_3
#                         aBs
#                            sub
#                               power_3
#                                  aBs
#                                     0
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_1
#                                           -2
#                   power_reverse_2
#                      power_reverse_1
#                         power_reverse_1
#                            power_2
#                               add
#                                  power_3
#                                     -2
#                                  power_reverse_4
#                                     add
#                                        x2
#                                        x2
#                sub
#                   sub
#                      cos
#                         power_3
#                            -2
#                      power_reverse_2
#                         power_reverse_1
#                            x1
#                   x1
#    power_2
#       x2
#
#
# _________________________________________________
# END OF RUN
# best_of_run attained at gen 38 and has f=1.0
# add
#    power_1
#       add
#          add
#             add
#                mul
#                   cos
#                      0
#                   sin
#                      0
#                0
#             power_reverse_4
#                0
#          power_2
#             x1
#       mul
#          sub
#             cos
#                power_3
#                   power_3
#                      aBs
#                         sub
#                            power_3
#                               aBs
#                                  0
#                            power_reverse_2
#                               power_reverse_1
#                                  power_reverse_2
#                                     power_reverse_1
#                                        power_reverse_1
#                                           power_2
#                                              add
#                                                 sub
#                                                    sub
#                                                       cos
#                                                          power_3
#                                                             -2
#                                                       power_reverse_2
#                                                          power_reverse_1
#                                                             x1
#                                                    x1
#                                                 power_reverse_4
#                                                    add
#                                                       x2
#                                                       x2
#             power_reverse_2
#                power_reverse_1
#                   power_reverse_1
#                      power_2
#                         cos
#                            power_3
#                               -2
#          sub
#             mul
#                x2
#                x2
#             sub
#                sub
#                   cos
#                      power_3
#                         aBs
#                            sub
#                               power_3
#                                  aBs
#                                     0
#                               power_reverse_2
#                                  power_reverse_1
#                                     power_reverse_1
#                                        power_1
#                                           -2
#                   power_reverse_2
#                      power_reverse_1
#                         power_reverse_1
#                            power_2
#                               add
#                                  power_3
#                                     -2
#                                  power_reverse_4
#                                     add
#                                        x2
#                                        x2
#                sub
#                   sub
#                      cos
#                         power_3
#                            -2
#                      power_reverse_2
#                         power_reverse_1
#                            x1
#                   x1
#    power_2
#       x2

# %%
# Out:
# 0.25477113377824295

# %%
# Out:
# -0.5
